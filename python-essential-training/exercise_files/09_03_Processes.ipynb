# %%
#!pip install multiprocess
from multiprocess import Process
import time
import threading

# %% [markdown]
# ## Processes

# %%
def longSquare(num, results):
    time.sleep(1)
    print(num**2)
    print('Finished computing!')

results = {}
processes = [Process(target=longSquare, args=(n,results)) for n in range(0, 10)]
[p.start() for p in processes]
[p.join() for p in processes]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
# %%time
results = {}
threads = [threading.Thread(target=longSquare, args=(n, results)) for n in range(0, 100)]
[t.start() for t in threads]
[t.join() for t in threads]
print(results)
# Out:
# 16401
# Finished computing!
#
# 9
# Finished computing!
#
# Finished computing!
#
# Finished computing!
# Finished computing!
# 25336425002401230422092116
# 640062415929
# Finished computing!
# 81
# Finished computing!
# 289
# Finished computing!
# 324
# Finished computing!
# 529
# Finished computing!
# 6766251024
# Finished computing!
#
# 3249
# Finished computing!
# 4624
# Finished computing!
# 6561
# Finished computing!
# 70567225
# Finished computing!
# 5329961
# Finished computing!
#
# 9025
#
# Finished computing!
# 1444
# Finished computing!
# 4225
# Finished computing!
# 169441
# Finished computing!
# 1225
# Finished computing!
# 9604176411564900
# Finished computing!
#
# Finished computing!
# 1521
# Finished computing!
# 1296
# Finished computing!
# 291638442601
# Finished computing!
# 5625
# Finished computing!
# 576
# 2704
# Finished computing!
# 3025
# Finished computing!
# 4761
# Finished computing!
# 98013600
# Finished computing!
# 1089
# 225
#
# 4489
# Finished computing!
#
# 2809
# Finished computing!
# 6724921677442025
# Finished computing!
# 72978450418464
# Finished computing!
# 196
# Finished computing!
# Finished computing!
# 8281
# Finished computing!
# 3136
# Finished computing!
# 5476
# Finished computing!
#
#
# 64
# Finished computing!
# 8649
# Finished computing!
# Finished computing!
# 900
# Finished computing!
# Finished computing!Finished computing!36
# Finished computing!
#
# 518449
# Finished computing!
#
#
#
# 40963721121
# Finished computing!
# Finished computing!1936
# Finished computing!
#
#
# Finished computing!144256Finished computing!13696084
#
#
#
# Finished computing!
#
# Finished computing!Finished computing!
# Finished computing!9409
# Finished computing!
# 3481
# Finished computing!
# Finished computing!Finished computing!
#
# Finished computing!
# 8100Finished computing!1600
# Finished computing!
# 73965776
# Finished computing!
#
# Finished computing!
#
#
#
# Finished computing!Finished computing!
#
#
#
#
#
#
# 7921
# Finished computing!
# Finished computing!Finished computing!
#
#
#
#
# 361
# Finished computing!
# 3969
# Finished computing!
#
#
# 1849
# Finished computing!
#
# Finished computing!
#
#
# Finished computing!Finished computing!Finished computing!
# Finished computing!
#
# Finished computing!Finished computing!Finished computing!Finished computing!Finished computing!88364848416889
#
#
#
#
#
#
#
# 100Finished computing!
# Finished computing!
#
#
# Finished computing!
# 1681
# Finished computing!
# Finished computing!
# 7569
# Finished computing!Finished computing!Finished computing!
#
#
#
# Finished computing!
# 400
# Finished computing!
# Finished computing!
#
# Finished computing!
# Finished computing!4356
# Finished computing!
#
#
#
#
#
#
# Finished computing!
# Finished computing!
# {}
# CPU times: total: 328 ms
# Wall time: 1.24 s
